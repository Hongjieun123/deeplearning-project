# %%
# Colab에서 tensorflow 1.x 실행
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime

mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)

print('\n', mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

print('\ntrain image shape = ', np.shape(mnist.train.images))
print('train label shape = ', np.shape(mnist.train.labels))
print('test image shape = ', np.shape(mnist.test.images))
print('test label shape = ', np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-2-b4762e5f4068>:6: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
learning_rate = 0.001
epochs = 30
batch_size = 100

# %%
X = tf.placeholder(tf.float32, [None, 784])

A1 = X_img = tf.reshape(X,[-1, 28, 28, 1])

T = tf.placeholder(tf.float32, [None, 10])  # image 28 X 28 X 1 (black/white)

# %%
# 1번째 컨볼루션 층
# 4X4 크기를 가지는 32개의 필터를 적용

F2 = tf.Variable(tf.random_normal([4, 4, 1, 32], stddev=0.01))  
b2 = tf.Variable(tf.constant(0.1, shape=[32]))   

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 32
C2 = tf.nn.conv2d(A1, F2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 32  => 14 X 14 X 32
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 2번째 컨볼루션 층
# 4X4 크기를 가지는 32개의 필터를 적용

F3 = tf.Variable(tf.random_normal([4, 4, 32, 32], stddev=0.01))  
b3 = tf.Variable(tf.constant(0.1, shape=[32]))   

# 2번째 컨볼루션 연산을 통해 14 X 14 X32  => 14 X 14 X 32
C3 = tf.nn.conv2d(A2, F3, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z3= tf.nn.relu(C3+b3)

# 2번째 max pooling을 통해 14 X 14 X 32  => 7 X 7 X 32
A3= P3 = tf.nn.max_pool(Z3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 7X7 크기를 가진 32개의 activation map을 flatten 시킴
A3_flat = P3_flat = tf.reshape(A3, [-1, 32*7*7])

# %%
# 출력층
W4 = tf.Variable(tf.random_normal([32*7*7, 10], stddev=0.01))
b4 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z4, 즉 softmax 에 들어가는 입력 값
Z4 = logits = tf.matmul(A3_flat, W4) + b4    # 선형회귀 값 Z4

y = A4 = tf.nn.softmax(Z4)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z4, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A4, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# index list 출력
accuracy_index = tf.cast(predicted_val, dtype=tf.float32)

# 예측값 처리
predicted_list = tf.argmax(A4, 1)

# %%
index_label_prediction_list = []

with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    # 30 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val, predicted_list_val, index_label = sess.run([accuracy, predicted_list, accuracy_index], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
    print("type(accuracy_val) = ", type(accuracy_val), ', type(predicted_list_val) = ', type(predicted_list_val), ', type(index_label) = ', type(index_label))
    print("index_label.shape = ", index_label.shape)
    
    index_label_list = list(index_label)
    print("length of index_label_list = ", len(index_label_list))
    print("false label count = ", index_label_list.count([0]))
        
    
    temp_list = [] 
    
    for index in range(len(index_label)):
        
        if index_label[index] == 0:
            
            temp_list.append(index)
            temp_list.append(np.argmax(test_t_data[index]))  # one-hot encoding 이므로 argmax 로 정답 추출
            temp_list.append(predicted_list_val[index])
            
            index_label_prediction_list.append(temp_list)
            
            temp_list = []
            
    print("\nlength of index_label_false_list", len(index_label_prediction_list))
# Out:
# epochs =  0 , step =  0 , loss_val =  2.7211032
# epochs =  0 , step =  100 , loss_val =  0.4671753
# epochs =  0 , step =  200 , loss_val =  0.43679214
# epochs =  0 , step =  300 , loss_val =  0.29045123
# epochs =  0 , step =  400 , loss_val =  0.15385813
# epochs =  0 , step =  500 , loss_val =  0.16883217
# epochs =  1 , step =  0 , loss_val =  0.14058654
# epochs =  1 , step =  100 , loss_val =  0.09964594
# epochs =  1 , step =  200 , loss_val =  0.09497233
# epochs =  1 , step =  300 , loss_val =  0.15362224
# epochs =  1 , step =  400 , loss_val =  0.046935864
# epochs =  1 , step =  500 , loss_val =  0.062505394
# epochs =  2 , step =  0 , loss_val =  0.053657617
# epochs =  2 , step =  100 , loss_val =  0.03780036
# epochs =  2 , step =  200 , loss_val =  0.06731679
# epochs =  2 , step =  300 , loss_val =  0.06160121
# epochs =  2 , step =  400 , loss_val =  0.0678081
# epochs =  2 , step =  500 , loss_val =  0.024052072
# epochs =  3 , step =  0 , loss_val =  0.076036245
# epochs =  3 , step =  100 , loss_val =  0.04292885
# epochs =  3 , step =  200 , loss_val =  0.09695675
# epochs =  3 , step =  300 , loss_val =  0.05246055
# epochs =  3 , step =  400 , loss_val =  0.075918935
# epochs =  3 , step =  500 , loss_val =  0.012917178
# epochs =  4 , step =  0 , loss_val =  0.04972012
# epochs =  4 , step =  100 , loss_val =  0.03582612
# epochs =  4 , step =  200 , loss_val =  0.08105001
# epochs =  4 , step =  300 , loss_val =  0.0072212745
# epochs =  4 , step =  400 , loss_val =  0.0997091
# epochs =  4 , step =  500 , loss_val =  0.03399009
# epochs =  5 , step =  0 , loss_val =  0.026682459
# epochs =  5 , step =  100 , loss_val =  0.01662999
# epochs =  5 , step =  200 , loss_val =  0.022893913
# epochs =  5 , step =  300 , loss_val =  0.03111286
# epochs =  5 , step =  400 , loss_val =  0.019388275
# epochs =  5 , step =  500 , loss_val =  0.02251857
# epochs =  6 , step =  0 , loss_val =  0.07609081
# epochs =  6 , step =  100 , loss_val =  0.008371352
# epochs =  6 , step =  200 , loss_val =  0.023085032
# epochs =  6 , step =  300 , loss_val =  0.02180337
# epochs =  6 , step =  400 , loss_val =  0.042903513
# epochs =  6 , step =  500 , loss_val =  0.01667257
# epochs =  7 , step =  0 , loss_val =  0.014329771
# epochs =  7 , step =  100 , loss_val =  0.080169775
# epochs =  7 , step =  200 , loss_val =  0.005748809
# epochs =  7 , step =  300 , loss_val =  0.10128698
# epochs =  7 , step =  400 , loss_val =  0.03992012
# epochs =  7 , step =  500 , loss_val =  0.012863498
# epochs =  8 , step =  0 , loss_val =  0.03909975
# epochs =  8 , step =  100 , loss_val =  0.05350849
# epochs =  8 , step =  200 , loss_val =  0.018353451
# epochs =  8 , step =  300 , loss_val =  0.12502699
# epochs =  8 , step =  400 , loss_val =  0.023341307
# epochs =  8 , step =  500 , loss_val =  0.017323662
# epochs =  9 , step =  0 , loss_val =  0.061969448
# epochs =  9 , step =  100 , loss_val =  0.026319899
# epochs =  9 , step =  200 , loss_val =  0.027473945
# epochs =  9 , step =  300 , loss_val =  0.060762953
# epochs =  9 , step =  400 , loss_val =  0.02924852
# epochs =  9 , step =  500 , loss_val =  0.04298718
# epochs =  10 , step =  0 , loss_val =  0.010346695
# epochs =  10 , step =  100 , loss_val =  0.022231748
# epochs =  10 , step =  200 , loss_val =  0.02070925
# epochs =  10 , step =  300 , loss_val =  0.006394427
# epochs =  10 , step =  400 , loss_val =  0.026229545
# epochs =  10 , step =  500 , loss_val =  0.011120051
# epochs =  11 , step =  0 , loss_val =  0.015080205
# epochs =  11 , step =  100 , loss_val =  0.041131955
# epochs =  11 , step =  200 , loss_val =  0.0026922033
# epochs =  11 , step =  300 , loss_val =  0.006342283
# epochs =  11 , step =  400 , loss_val =  0.015701089
# epochs =  11 , step =  500 , loss_val =  0.018582474
# epochs =  12 , step =  0 , loss_val =  0.0032226036
# epochs =  12 , step =  100 , loss_val =  0.0066844826
# epochs =  12 , step =  200 , loss_val =  0.004467457
# epochs =  12 , step =  300 , loss_val =  0.06739624
# epochs =  12 , step =  400 , loss_val =  0.00938025
# epochs =  12 , step =  500 , loss_val =  0.00047815221
# epochs =  13 , step =  0 , loss_val =  0.0022800027
# epochs =  13 , step =  100 , loss_val =  0.020531397
# epochs =  13 , step =  200 , loss_val =  0.013416591
# epochs =  13 , step =  300 , loss_val =  0.019496383
# epochs =  13 , step =  400 , loss_val =  0.021665335
# epochs =  13 , step =  500 , loss_val =  0.040073086
# epochs =  14 , step =  0 , loss_val =  0.0025282325
# epochs =  14 , step =  100 , loss_val =  0.0029413225
# epochs =  14 , step =  200 , loss_val =  0.008555267
# epochs =  14 , step =  300 , loss_val =  0.0123802805
# epochs =  14 , step =  400 , loss_val =  0.005935046
# epochs =  14 , step =  500 , loss_val =  0.012358571
# epochs =  15 , step =  0 , loss_val =  0.019445224
# epochs =  15 , step =  100 , loss_val =  0.002331142
# epochs =  15 , step =  200 , loss_val =  0.0072479635
# epochs =  15 , step =  300 , loss_val =  0.010293343
# epochs =  15 , step =  400 , loss_val =  0.01320611
# epochs =  15 , step =  500 , loss_val =  0.035376254
# epochs =  16 , step =  0 , loss_val =  0.0032171418
# epochs =  16 , step =  100 , loss_val =  0.0038132847
# epochs =  16 , step =  200 , loss_val =  0.011494056
# epochs =  16 , step =  300 , loss_val =  0.0032138603
# epochs =  16 , step =  400 , loss_val =  0.01846759
# epochs =  16 , step =  500 , loss_val =  0.0010331373
# epochs =  17 , step =  0 , loss_val =  0.017400693
# epochs =  17 , step =  100 , loss_val =  0.0021163286
# epochs =  17 , step =  200 , loss_val =  0.019215249
# epochs =  17 , step =  300 , loss_val =  0.029329251
# epochs =  17 , step =  400 , loss_val =  0.017144816
# epochs =  17 , step =  500 , loss_val =  0.022360114
# epochs =  18 , step =  0 , loss_val =  0.035585422
# epochs =  18 , step =  100 , loss_val =  0.0023847818
# epochs =  18 , step =  200 , loss_val =  0.010417094
# epochs =  18 , step =  300 , loss_val =  0.011272751
# epochs =  18 , step =  400 , loss_val =  0.0014150332
# epochs =  18 , step =  500 , loss_val =  0.0010326264
# epochs =  19 , step =  0 , loss_val =  0.00038511163
# epochs =  19 , step =  100 , loss_val =  0.0012364804
# epochs =  19 , step =  200 , loss_val =  0.0005115585
# epochs =  19 , step =  300 , loss_val =  0.0014566315
# epochs =  19 , step =  400 , loss_val =  0.0042800484
# epochs =  19 , step =  500 , loss_val =  0.017537277
# epochs =  20 , step =  0 , loss_val =  0.0135120265
# epochs =  20 , step =  100 , loss_val =  0.001545972
# epochs =  20 , step =  200 , loss_val =  0.0015941188
# epochs =  20 , step =  300 , loss_val =  0.023814974
# epochs =  20 , step =  400 , loss_val =  0.0058269612
# epochs =  20 , step =  500 , loss_val =  0.00044030233
# epochs =  21 , step =  0 , loss_val =  0.0017621632
# epochs =  21 , step =  100 , loss_val =  0.017798463
# epochs =  21 , step =  200 , loss_val =  0.0055262865
# epochs =  21 , step =  300 , loss_val =  0.0074785883
# epochs =  21 , step =  400 , loss_val =  0.019880628
# epochs =  21 , step =  500 , loss_val =  0.010336127
# epochs =  22 , step =  0 , loss_val =  0.0012921311
# epochs =  22 , step =  100 , loss_val =  0.00786469
# epochs =  22 , step =  200 , loss_val =  0.0012472139
# epochs =  22 , step =  300 , loss_val =  0.014401265
# epochs =  22 , step =  400 , loss_val =  0.0011556837
# epochs =  22 , step =  500 , loss_val =  0.004608354
# epochs =  23 , step =  0 , loss_val =  0.0002732417
# epochs =  23 , step =  100 , loss_val =  0.012195536
# epochs =  23 , step =  200 , loss_val =  0.0029172655
# epochs =  23 , step =  300 , loss_val =  0.008234862
# epochs =  23 , step =  400 , loss_val =  0.0073684966
# epochs =  23 , step =  500 , loss_val =  0.009732093
# epochs =  24 , step =  0 , loss_val =  0.007535935
# epochs =  24 , step =  100 , loss_val =  0.007068138
# epochs =  24 , step =  200 , loss_val =  0.00021055888
# epochs =  24 , step =  300 , loss_val =  0.018094087
# epochs =  24 , step =  400 , loss_val =  0.004899531
# epochs =  24 , step =  500 , loss_val =  0.0012944017
# epochs =  25 , step =  0 , loss_val =  0.0004133188
# epochs =  25 , step =  100 , loss_val =  0.0036079078
# epochs =  25 , step =  200 , loss_val =  0.0034467054
# epochs =  25 , step =  300 , loss_val =  3.3458302e-05
# epochs =  25 , step =  400 , loss_val =  0.0028667962
# epochs =  25 , step =  500 , loss_val =  0.04056779
# epochs =  26 , step =  0 , loss_val =  0.0010630115
# epochs =  26 , step =  100 , loss_val =  4.8659144e-06
# epochs =  26 , step =  200 , loss_val =  0.0049287565
# epochs =  26 , step =  300 , loss_val =  0.01363861
# epochs =  26 , step =  400 , loss_val =  0.0036214658
# epochs =  26 , step =  500 , loss_val =  0.0022946058
# epochs =  27 , step =  0 , loss_val =  0.014477628
# epochs =  27 , step =  100 , loss_val =  0.0057153236
# epochs =  27 , step =  200 , loss_val =  0.0006134406
# epochs =  27 , step =  300 , loss_val =  0.007749562
# epochs =  27 , step =  400 , loss_val =  0.0014178365
# epochs =  27 , step =  500 , loss_val =  0.0054925773
# epochs =  28 , step =  0 , loss_val =  0.0076051354
# epochs =  28 , step =  100 , loss_val =  0.0018196786
# epochs =  28 , step =  200 , loss_val =  0.037377417
# epochs =  28 , step =  300 , loss_val =  0.00028644706
# epochs =  28 , step =  400 , loss_val =  0.009320246
# epochs =  28 , step =  500 , loss_val =  0.00092986313
# epochs =  29 , step =  0 , loss_val =  0.0014319965
# epochs =  29 , step =  100 , loss_val =  0.008395326
# epochs =  29 , step =  200 , loss_val =  0.008209674
# epochs =  29 , step =  300 , loss_val =  0.0023176395
# epochs =  29 , step =  400 , loss_val =  0.0017769998
# epochs =  29 , step =  500 , loss_val =  0.01993803
#
# elapsed time =  0:29:21.740930
#
# Accuracy =  0.988
# type(accuracy_val) =  <class 'numpy.float32'> , type(predicted_list_val) =  <class 'numpy.ndarray'> , type(index_label) =  <class 'numpy.ndarray'>
# index_label.shape =  (10000,)
# length of index_label_list =  10000
# false label count =  120
#
# length of index_label_false_list 120
