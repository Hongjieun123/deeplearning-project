# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime

mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)

print('\n', mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

print('\ntrain image shape = ', np.shape(mnist.train.images))
print('train label shape = ', np.shape(mnist.train.labels))
print('test image shape = ', np.shape(mnist.test.images))
print('test label shape = ', np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-1-b4762e5f4068>:6: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\HONG\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\HONG\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Users\HONG\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\HONG\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\HONG\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
learning_rate = 0.001
epochs = 30
batch_size = 100

# %%
X = tf.placeholder(tf.float32, [None, 784])

A1 = X_img = tf.reshape(X,[-1, 28, 28, 1])

T = tf.placeholder(tf.float32, [None, 10])  # image 28 X 28 X 1 (black/white)

# %%
# 1번째 컨볼루션 층
# 4X4 크기를 가지는 32개의 필터를 적용

F2 = tf.Variable(tf.random_normal([4, 4, 1, 32], stddev=0.01))  
b2 = tf.Variable(tf.constant(0.1, shape=[32]))   

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 32
C2 = tf.nn.conv2d(A1, F2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 32  => 14 X 14 X 32
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 2번째 컨볼루션 층
# 4X4 크기를 가지는 32개의 필터를 적용

F3 = tf.Variable(tf.random_normal([4, 4, 32, 32], stddev=0.01))  
b3 = tf.Variable(tf.constant(0.1, shape=[32]))   

# 2번째 컨볼루션 연산을 통해 14 X 14 X32  => 14 X 14 X 32
C3 = tf.nn.conv2d(A2, F3, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z3= tf.nn.relu(C3+b3)

# 2번째 max pooling을 통해 14 X 14 X 32  => 7 X 7 X 32
A3= P3 = tf.nn.max_pool(Z3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 7X7 크기를 가진 32개의 activation map을 flatten 시킴
A3_flat = P3_flat = tf.reshape(A3, [-1, 32*7*7])

# %%
# 출력층
W4 = tf.Variable(tf.random_normal([32*7*7, 10], stddev=0.01))
b4 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z4, 즉 softmax 에 들어가는 입력 값
Z4 = logits = tf.matmul(A3_flat, W4) + b4    # 선형회귀 값 Z4

y = A4 = tf.nn.softmax(Z4)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z4, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A4, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# index list 출력
accuracy_index = tf.cast(predicted_val, dtype=tf.float32)

# 예측값 처리
predicted_list = tf.argmax(A4, 1)

# %%
index_label_prediction_list = []

with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    # 30 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val, predicted_list_val, index_label = sess.run([accuracy, predicted_list, accuracy_index], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
    print("type(accuracy_val) = ", type(accuracy_val), ', type(predicted_list_val) = ', type(predicted_list_val), ', type(index_label) = ', type(index_label))
    print("index_label.shape = ", index_label.shape)
    
    index_label_list = list(index_label)
    print("length of index_label_list = ", len(index_label_list))
    print("false label count = ", index_label_list.count([0]))
        
    
    temp_list = [] 
    
    for index in range(len(index_label)):
        
        if index_label[index] == 0:
            
            temp_list.append(index)
            temp_list.append(np.argmax(test_t_data[index]))  # one-hot encoding 이므로 argmax 로 정답 추출
            temp_list.append(predicted_list_val[index])
            
            index_label_prediction_list.append(temp_list)
            
            temp_list = []
            
    print("\nlength of index_label_false_list", len(index_label_prediction_list))
# Out:
# epochs =  0 , step =  0 , loss_val =  2.763648
# epochs =  0 , step =  100 , loss_val =  0.6796249
# epochs =  0 , step =  200 , loss_val =  0.133212
# epochs =  0 , step =  300 , loss_val =  0.21291359
# epochs =  0 , step =  400 , loss_val =  0.15110402
# epochs =  0 , step =  500 , loss_val =  0.08785078
# epochs =  1 , step =  0 , loss_val =  0.15817241
# epochs =  1 , step =  100 , loss_val =  0.092111625
# epochs =  1 , step =  200 , loss_val =  0.11375617
# epochs =  1 , step =  300 , loss_val =  0.033528324
# epochs =  1 , step =  400 , loss_val =  0.013425091
# epochs =  1 , step =  500 , loss_val =  0.086493775
# epochs =  2 , step =  0 , loss_val =  0.12926923
# epochs =  2 , step =  100 , loss_val =  0.12172766
# epochs =  2 , step =  200 , loss_val =  0.010145438
# epochs =  2 , step =  300 , loss_val =  0.06469767
# epochs =  2 , step =  400 , loss_val =  0.047810823
# epochs =  2 , step =  500 , loss_val =  0.04402612
# epochs =  3 , step =  0 , loss_val =  0.03338689
# epochs =  3 , step =  100 , loss_val =  0.04975282
# epochs =  3 , step =  200 , loss_val =  0.009253135
# epochs =  3 , step =  300 , loss_val =  0.05783348
# epochs =  3 , step =  400 , loss_val =  0.008257736
# epochs =  3 , step =  500 , loss_val =  0.049256075
# epochs =  4 , step =  0 , loss_val =  0.021078866
# epochs =  4 , step =  100 , loss_val =  0.112638816
# epochs =  4 , step =  200 , loss_val =  0.053607766
# epochs =  4 , step =  300 , loss_val =  0.040888127
# epochs =  4 , step =  400 , loss_val =  0.038886685
# epochs =  4 , step =  500 , loss_val =  0.010592845
# epochs =  5 , step =  0 , loss_val =  0.011685166
# epochs =  5 , step =  100 , loss_val =  0.0062061776
# epochs =  5 , step =  200 , loss_val =  0.02311671
# epochs =  5 , step =  300 , loss_val =  0.043972686
# epochs =  5 , step =  400 , loss_val =  0.048416242
# epochs =  5 , step =  500 , loss_val =  0.009825472
# epochs =  6 , step =  0 , loss_val =  0.025260722
# epochs =  6 , step =  100 , loss_val =  0.0069275214
# epochs =  6 , step =  200 , loss_val =  0.077870205
# epochs =  6 , step =  300 , loss_val =  0.021095099
# epochs =  6 , step =  400 , loss_val =  0.042466115
# epochs =  6 , step =  500 , loss_val =  0.023999128
# epochs =  7 , step =  0 , loss_val =  0.06302565
# epochs =  7 , step =  100 , loss_val =  0.007395288
# epochs =  7 , step =  200 , loss_val =  0.022374202
# epochs =  7 , step =  300 , loss_val =  0.0421302
# epochs =  7 , step =  400 , loss_val =  0.010013785
# epochs =  7 , step =  500 , loss_val =  0.01876363
# epochs =  8 , step =  0 , loss_val =  0.0031338902
# epochs =  8 , step =  100 , loss_val =  0.015070775
# epochs =  8 , step =  200 , loss_val =  0.013358742
# epochs =  8 , step =  300 , loss_val =  0.022084968
# epochs =  8 , step =  400 , loss_val =  0.008789878
# epochs =  8 , step =  500 , loss_val =  0.026773209
# epochs =  9 , step =  0 , loss_val =  0.04458053
# epochs =  9 , step =  100 , loss_val =  0.009751985
# epochs =  9 , step =  200 , loss_val =  0.003056822
# epochs =  9 , step =  300 , loss_val =  0.0020294155
# epochs =  9 , step =  400 , loss_val =  0.0037744162
# epochs =  9 , step =  500 , loss_val =  0.002815067
# epochs =  10 , step =  0 , loss_val =  0.012525759
# epochs =  10 , step =  100 , loss_val =  0.018106956
# epochs =  10 , step =  200 , loss_val =  0.008218917
# epochs =  10 , step =  300 , loss_val =  0.0060293823
# epochs =  10 , step =  400 , loss_val =  0.0038213516
# epochs =  10 , step =  500 , loss_val =  0.010055939
# epochs =  11 , step =  0 , loss_val =  0.015712177
# epochs =  11 , step =  100 , loss_val =  0.007933074
# epochs =  11 , step =  200 , loss_val =  0.0016331428
# epochs =  11 , step =  300 , loss_val =  0.0034629079
# epochs =  11 , step =  400 , loss_val =  0.011862835
# epochs =  11 , step =  500 , loss_val =  0.0126778
# epochs =  12 , step =  0 , loss_val =  0.037380237
# epochs =  12 , step =  100 , loss_val =  0.003452249
# epochs =  12 , step =  200 , loss_val =  0.032086495
# epochs =  12 , step =  300 , loss_val =  0.007015861
# epochs =  12 , step =  400 , loss_val =  0.028037913
# epochs =  12 , step =  500 , loss_val =  0.030193474
# epochs =  13 , step =  0 , loss_val =  0.0226256
# epochs =  13 , step =  100 , loss_val =  0.018938692
# epochs =  13 , step =  200 , loss_val =  0.006011008
# epochs =  13 , step =  300 , loss_val =  0.0019845252
# epochs =  13 , step =  400 , loss_val =  0.00942727
# epochs =  13 , step =  500 , loss_val =  0.06295456
# epochs =  14 , step =  0 , loss_val =  0.015473736
# epochs =  14 , step =  100 , loss_val =  0.00064178766
# epochs =  14 , step =  200 , loss_val =  0.003742585
# epochs =  14 , step =  300 , loss_val =  0.0046146037
# epochs =  14 , step =  400 , loss_val =  0.05570349
# epochs =  14 , step =  500 , loss_val =  0.018982256
# epochs =  15 , step =  0 , loss_val =  0.0033037318
# epochs =  15 , step =  100 , loss_val =  0.07732664
# epochs =  15 , step =  200 , loss_val =  0.0033989667
# epochs =  15 , step =  300 , loss_val =  0.0013964289
# epochs =  15 , step =  400 , loss_val =  0.10497792
# epochs =  15 , step =  500 , loss_val =  0.0017550476
# epochs =  16 , step =  0 , loss_val =  0.007217496
# epochs =  16 , step =  100 , loss_val =  0.04082871
# epochs =  16 , step =  200 , loss_val =  0.03198178
# epochs =  16 , step =  300 , loss_val =  0.0029806218
# epochs =  16 , step =  400 , loss_val =  0.0008850167
# epochs =  16 , step =  500 , loss_val =  0.0043590833
# epochs =  17 , step =  0 , loss_val =  0.004543294
# epochs =  17 , step =  100 , loss_val =  0.00079166365
# epochs =  17 , step =  200 , loss_val =  0.003838936
# epochs =  17 , step =  300 , loss_val =  0.020182244
# epochs =  17 , step =  400 , loss_val =  0.0016376245
# epochs =  17 , step =  500 , loss_val =  0.0007810417
# epochs =  18 , step =  0 , loss_val =  0.0013477969
# epochs =  18 , step =  100 , loss_val =  0.0010871419
# epochs =  18 , step =  200 , loss_val =  0.0010197611
# epochs =  18 , step =  300 , loss_val =  0.027481243
# epochs =  18 , step =  400 , loss_val =  0.012816881
# epochs =  18 , step =  500 , loss_val =  0.009550255
# epochs =  19 , step =  0 , loss_val =  0.00045164087
# epochs =  19 , step =  100 , loss_val =  0.00045008762
# epochs =  19 , step =  200 , loss_val =  0.0010575077
# epochs =  19 , step =  300 , loss_val =  0.0006841466
# epochs =  19 , step =  400 , loss_val =  0.007717004
# epochs =  19 , step =  500 , loss_val =  0.03096686
# epochs =  20 , step =  0 , loss_val =  8.840889e-05
# epochs =  20 , step =  100 , loss_val =  0.0024578872
# epochs =  20 , step =  200 , loss_val =  0.011217719
# epochs =  20 , step =  300 , loss_val =  0.0033658044
# epochs =  20 , step =  400 , loss_val =  0.02675597
# epochs =  20 , step =  500 , loss_val =  0.00069931545
# epochs =  21 , step =  0 , loss_val =  0.00037277222
# epochs =  21 , step =  100 , loss_val =  0.000190076
# epochs =  21 , step =  200 , loss_val =  0.007005979
# epochs =  21 , step =  300 , loss_val =  0.0008530769
# epochs =  21 , step =  400 , loss_val =  0.0007447826
# epochs =  21 , step =  500 , loss_val =  0.00992372
# epochs =  22 , step =  0 , loss_val =  0.00050337415
# epochs =  22 , step =  100 , loss_val =  0.00031891573
# epochs =  22 , step =  200 , loss_val =  0.018333424
# epochs =  22 , step =  300 , loss_val =  0.006049614
# epochs =  22 , step =  400 , loss_val =  0.0030085936
# epochs =  22 , step =  500 , loss_val =  0.0006999588
# epochs =  23 , step =  0 , loss_val =  0.0005412354
# epochs =  23 , step =  100 , loss_val =  0.007881811
# epochs =  23 , step =  200 , loss_val =  5.932828e-05
# epochs =  23 , step =  300 , loss_val =  0.005864423
# epochs =  23 , step =  400 , loss_val =  0.0016517673
# epochs =  23 , step =  500 , loss_val =  0.0012485634
# epochs =  24 , step =  0 , loss_val =  0.00084490894
# epochs =  24 , step =  100 , loss_val =  0.017546734
# epochs =  24 , step =  200 , loss_val =  0.0077515203
# epochs =  24 , step =  300 , loss_val =  0.0024551277
# epochs =  24 , step =  400 , loss_val =  0.00981093
# epochs =  24 , step =  500 , loss_val =  0.00033810362
# epochs =  25 , step =  0 , loss_val =  0.00019212096
# epochs =  25 , step =  100 , loss_val =  0.00022576567
# epochs =  25 , step =  200 , loss_val =  0.00050002785
# epochs =  25 , step =  300 , loss_val =  0.0014758438
# epochs =  25 , step =  400 , loss_val =  0.00041269994
# epochs =  25 , step =  500 , loss_val =  0.0001803047
# epochs =  26 , step =  0 , loss_val =  0.002994138
# epochs =  26 , step =  100 , loss_val =  0.0019893527
# epochs =  26 , step =  200 , loss_val =  0.0001234052
# epochs =  26 , step =  300 , loss_val =  0.0001329819
# epochs =  26 , step =  400 , loss_val =  0.00016336638
# epochs =  26 , step =  500 , loss_val =  0.00042462588
# epochs =  27 , step =  0 , loss_val =  0.00038724553
# epochs =  27 , step =  100 , loss_val =  0.0031375792
# epochs =  27 , step =  200 , loss_val =  2.8688582e-05
# epochs =  27 , step =  300 , loss_val =  0.003955818
# epochs =  27 , step =  400 , loss_val =  0.005040657
# epochs =  27 , step =  500 , loss_val =  0.007140511
# epochs =  28 , step =  0 , loss_val =  0.010724464
# epochs =  28 , step =  100 , loss_val =  7.009948e-05
# epochs =  28 , step =  200 , loss_val =  0.00021332767
# epochs =  28 , step =  300 , loss_val =  0.00029303596
# epochs =  28 , step =  400 , loss_val =  0.0012533732
# epochs =  28 , step =  500 , loss_val =  0.076722175
# epochs =  29 , step =  0 , loss_val =  0.0008861614
# epochs =  29 , step =  100 , loss_val =  0.0022874924
# epochs =  29 , step =  200 , loss_val =  0.000583882
# epochs =  29 , step =  300 , loss_val =  0.00012856335
# epochs =  29 , step =  400 , loss_val =  0.0006544635
# epochs =  29 , step =  500 , loss_val =  0.010187797
#
# elapsed time =  0:58:11.129349
#
# Accuracy =  0.9882
# type(accuracy_val) =  <class 'numpy.float32'> , type(predicted_list_val) =  <class 'numpy.ndarray'> , type(index_label) =  <class 'numpy.ndarray'>
# index_label.shape =  (10000,)
# length of index_label_list =  10000
# false label count =  118
#
# length of index_label_false_list 118
