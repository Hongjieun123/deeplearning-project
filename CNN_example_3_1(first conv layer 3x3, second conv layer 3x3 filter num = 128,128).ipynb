# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime

mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)

print('\n', mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

print('\ntrain image shape = ', np.shape(mnist.train.images))
print('train label shape = ', np.shape(mnist.train.labels))
print('test image shape = ', np.shape(mnist.test.images))
print('test label shape = ', np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-1-b4762e5f4068>:6: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\HONG\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\HONG\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Users\HONG\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\HONG\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\HONG\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
learning_rate = 0.001
epochs = 30
batch_size = 100

# %%
X = tf.placeholder(tf.float32, [None, 784])

A1 = X_img = tf.reshape(X,[-1, 28, 28, 1])

T = tf.placeholder(tf.float32, [None, 10])  # image 28 X 28 X 1 (black/white)

# %%
# 1번째 컨볼루션 층
# 3X3 크기를 가지는 128개의 필터를 적용

F2 = tf.Variable(tf.random_normal([3, 3, 1, 128], stddev=0.01))  
b2 = tf.Variable(tf.constant(0.1, shape=[128]))   

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 128
C2 = tf.nn.conv2d(A1, F2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 128  => 14 X 14 X 128
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 2번째 컨볼루션 층
# 3X3 크기를 가지는 32개의 필터를 적용

F3 = tf.Variable(tf.random_normal([3, 3, 128, 128], stddev=0.01))  
b3 = tf.Variable(tf.constant(0.1, shape=[128]))   

# 2번째 컨볼루션 연산을 통해 14 X 14 X128  => 14 X 14 X 128
C3 = tf.nn.conv2d(A2, F3, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z3= tf.nn.relu(C3+b3)

# 2번째 max pooling을 통해 14 X 14 X 128  => 7 X 7 X 128
A3= P3 = tf.nn.max_pool(Z3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 7X7 크기를 가진 32개의 activation map을 flatten 시킴
A3_flat = P3_flat = tf.reshape(A3, [-1, 128*7*7])

# %%
# 출력층
W4 = tf.Variable(tf.random_normal([128*7*7, 10], stddev=0.01))
b4 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z4, 즉 softmax 에 들어가는 입력 값
Z4 = logits = tf.matmul(A3_flat, W4) + b4    # 선형회귀 값 Z4

y = A4 = tf.nn.softmax(Z4)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z4, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A4, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# index list 출력
accuracy_index = tf.cast(predicted_val, dtype=tf.float32)

# 예측값 처리
predicted_list = tf.argmax(A4, 1)

# %%
index_label_prediction_list = []

with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    # 30 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val, predicted_list_val, index_label = sess.run([accuracy, predicted_list, accuracy_index], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
    print("type(accuracy_val) = ", type(accuracy_val), ', type(predicted_list_val) = ', type(predicted_list_val), ', type(index_label) = ', type(index_label))
    print("index_label.shape = ", index_label.shape)
    
    index_label_list = list(index_label)
    print("length of index_label_list = ", len(index_label_list))
    print("false label count = ", index_label_list.count([0]))
        
    
    temp_list = [] 
    
    for index in range(len(index_label)):
        
        if index_label[index] == 0:
            
            temp_list.append(index)
            temp_list.append(np.argmax(test_t_data[index]))  # one-hot encoding 이므로 argmax 로 정답 추출
            temp_list.append(predicted_list_val[index])
            
            index_label_prediction_list.append(temp_list)
            
            temp_list = []
            
    print("\nlength of index_label_false_list", len(index_label_prediction_list))
# Out:
# epochs =  0 , step =  0 , loss_val =  3.054024
# epochs =  0 , step =  100 , loss_val =  0.48888204
# epochs =  0 , step =  200 , loss_val =  0.28395286
# epochs =  0 , step =  300 , loss_val =  0.09385636
# epochs =  0 , step =  400 , loss_val =  0.10122346
# epochs =  0 , step =  500 , loss_val =  0.06261156
# epochs =  1 , step =  0 , loss_val =  0.08064474
# epochs =  1 , step =  100 , loss_val =  0.07560871
# epochs =  1 , step =  200 , loss_val =  0.046178192
# epochs =  1 , step =  300 , loss_val =  0.08241472
# epochs =  1 , step =  400 , loss_val =  0.1423751
# epochs =  1 , step =  500 , loss_val =  0.08051302
# epochs =  2 , step =  0 , loss_val =  0.048763357
# epochs =  2 , step =  100 , loss_val =  0.018472118
# epochs =  2 , step =  200 , loss_val =  0.0972567
# epochs =  2 , step =  300 , loss_val =  0.084989965
# epochs =  2 , step =  400 , loss_val =  0.09003889
# epochs =  2 , step =  500 , loss_val =  0.028771427
# epochs =  3 , step =  0 , loss_val =  0.053969216
# epochs =  3 , step =  100 , loss_val =  0.030248975
# epochs =  3 , step =  200 , loss_val =  0.0490988
# epochs =  3 , step =  300 , loss_val =  0.026942383
# epochs =  3 , step =  400 , loss_val =  0.05238761
# epochs =  3 , step =  500 , loss_val =  0.09221747
# epochs =  4 , step =  0 , loss_val =  0.04043369
# epochs =  4 , step =  100 , loss_val =  0.059367996
# epochs =  4 , step =  200 , loss_val =  0.04244173
# epochs =  4 , step =  300 , loss_val =  0.010559922
# epochs =  4 , step =  400 , loss_val =  0.008888082
# epochs =  4 , step =  500 , loss_val =  0.027153693
# epochs =  5 , step =  0 , loss_val =  0.08936408
# epochs =  5 , step =  100 , loss_val =  0.06673056
# epochs =  5 , step =  200 , loss_val =  0.08099274
# epochs =  5 , step =  300 , loss_val =  0.043706626
# epochs =  5 , step =  400 , loss_val =  0.10244459
# epochs =  5 , step =  500 , loss_val =  0.002787485
# epochs =  6 , step =  0 , loss_val =  0.017066542
# epochs =  6 , step =  100 , loss_val =  0.0076976586
# epochs =  6 , step =  200 , loss_val =  0.003663364
# epochs =  6 , step =  300 , loss_val =  0.06046273
# epochs =  6 , step =  400 , loss_val =  0.005796156
# epochs =  6 , step =  500 , loss_val =  0.0020892392
# epochs =  7 , step =  0 , loss_val =  0.027506363
# epochs =  7 , step =  100 , loss_val =  0.0045267097
# epochs =  7 , step =  200 , loss_val =  0.0079565095
# epochs =  7 , step =  300 , loss_val =  0.010545794
# epochs =  7 , step =  400 , loss_val =  0.008667788
# epochs =  7 , step =  500 , loss_val =  0.004667112
# epochs =  8 , step =  0 , loss_val =  0.0022475445
# epochs =  8 , step =  100 , loss_val =  0.0042292145
# epochs =  8 , step =  200 , loss_val =  0.0013508749
# epochs =  8 , step =  300 , loss_val =  0.019246198
# epochs =  8 , step =  400 , loss_val =  0.03823774
# epochs =  8 , step =  500 , loss_val =  0.003149471
# epochs =  9 , step =  0 , loss_val =  0.017882107
# epochs =  9 , step =  100 , loss_val =  0.024912352
# epochs =  9 , step =  200 , loss_val =  0.004152281
# epochs =  9 , step =  300 , loss_val =  0.010591401
# epochs =  9 , step =  400 , loss_val =  0.018775158
# epochs =  9 , step =  500 , loss_val =  0.014257306
# epochs =  10 , step =  0 , loss_val =  0.005683595
# epochs =  10 , step =  100 , loss_val =  0.0033753398
# epochs =  10 , step =  200 , loss_val =  0.0031156046
# epochs =  10 , step =  300 , loss_val =  0.026702104
# epochs =  10 , step =  400 , loss_val =  0.11573785
# epochs =  10 , step =  500 , loss_val =  0.011131037
# epochs =  11 , step =  0 , loss_val =  0.00052293553
# epochs =  11 , step =  100 , loss_val =  0.009012153
# epochs =  11 , step =  200 , loss_val =  0.0006738195
# epochs =  11 , step =  300 , loss_val =  0.014141116
# epochs =  11 , step =  400 , loss_val =  0.022336585
# epochs =  11 , step =  500 , loss_val =  0.0038622152
# epochs =  12 , step =  0 , loss_val =  0.006714684
# epochs =  12 , step =  100 , loss_val =  0.0018848105
# epochs =  12 , step =  200 , loss_val =  0.008876461
# epochs =  12 , step =  300 , loss_val =  0.010793201
# epochs =  12 , step =  400 , loss_val =  0.00078336836
# epochs =  12 , step =  500 , loss_val =  0.00046155453
# epochs =  13 , step =  0 , loss_val =  0.0023311262
# epochs =  13 , step =  100 , loss_val =  0.0025384424
# epochs =  13 , step =  200 , loss_val =  0.004485579
# epochs =  13 , step =  300 , loss_val =  0.020264003
# epochs =  13 , step =  400 , loss_val =  0.0029507983
# epochs =  13 , step =  500 , loss_val =  0.0015217257
# epochs =  14 , step =  0 , loss_val =  0.0025888137
# epochs =  14 , step =  100 , loss_val =  0.00020696889
# epochs =  14 , step =  200 , loss_val =  0.0006214218
# epochs =  14 , step =  300 , loss_val =  0.00465791
# epochs =  14 , step =  400 , loss_val =  0.0013989698
# epochs =  14 , step =  500 , loss_val =  0.007579043
# epochs =  15 , step =  0 , loss_val =  0.03334866
# epochs =  15 , step =  100 , loss_val =  0.008378341
# epochs =  15 , step =  200 , loss_val =  0.011646545
# epochs =  15 , step =  300 , loss_val =  0.004109765
# epochs =  15 , step =  400 , loss_val =  0.0011992673
# epochs =  15 , step =  500 , loss_val =  0.0006581345
# epochs =  16 , step =  0 , loss_val =  0.0029946174
# epochs =  16 , step =  100 , loss_val =  0.0019557464
# epochs =  16 , step =  200 , loss_val =  0.0004394356
# epochs =  16 , step =  300 , loss_val =  0.018910391
# epochs =  16 , step =  400 , loss_val =  0.0016645123
# epochs =  16 , step =  500 , loss_val =  0.001280657
# epochs =  17 , step =  0 , loss_val =  0.03246213
# epochs =  17 , step =  100 , loss_val =  0.0051692547
# epochs =  17 , step =  200 , loss_val =  0.001657042
# epochs =  17 , step =  300 , loss_val =  0.0020052707
# epochs =  17 , step =  400 , loss_val =  0.0020265921
# epochs =  17 , step =  500 , loss_val =  0.00032489625
# epochs =  18 , step =  0 , loss_val =  0.0021767814
# epochs =  18 , step =  100 , loss_val =  0.0042822165
# epochs =  18 , step =  200 , loss_val =  0.0011018113
# epochs =  18 , step =  300 , loss_val =  0.0021436086
# epochs =  18 , step =  400 , loss_val =  0.0015816032
# epochs =  18 , step =  500 , loss_val =  0.0019399289
# epochs =  19 , step =  0 , loss_val =  0.030806432
# epochs =  19 , step =  100 , loss_val =  0.014006662
# epochs =  19 , step =  200 , loss_val =  0.010590988
# epochs =  19 , step =  300 , loss_val =  0.00050348206
# epochs =  19 , step =  400 , loss_val =  0.0028221812
# epochs =  19 , step =  500 , loss_val =  0.00011532739
# epochs =  20 , step =  0 , loss_val =  0.00024210085
# epochs =  20 , step =  100 , loss_val =  0.00011480515
# epochs =  20 , step =  200 , loss_val =  0.009712827
# epochs =  20 , step =  300 , loss_val =  0.00013097447
# epochs =  20 , step =  400 , loss_val =  0.0021526357
# epochs =  20 , step =  500 , loss_val =  0.00072453625
# epochs =  21 , step =  0 , loss_val =  0.00236004
# epochs =  21 , step =  100 , loss_val =  0.0016757967
# epochs =  21 , step =  200 , loss_val =  0.003511155
# epochs =  21 , step =  300 , loss_val =  0.0031998442
# epochs =  21 , step =  400 , loss_val =  0.0049520493
# epochs =  21 , step =  500 , loss_val =  0.0025772136
# epochs =  22 , step =  0 , loss_val =  1.8306315e-05
# epochs =  22 , step =  100 , loss_val =  0.00093520165
# epochs =  22 , step =  200 , loss_val =  0.00048561554
# epochs =  22 , step =  300 , loss_val =  0.0050845016
# epochs =  22 , step =  400 , loss_val =  0.0011543579
# epochs =  22 , step =  500 , loss_val =  0.00075716345
# epochs =  23 , step =  0 , loss_val =  0.00044867955
# epochs =  23 , step =  100 , loss_val =  0.008149583
# epochs =  23 , step =  200 , loss_val =  0.0010940577
# epochs =  23 , step =  300 , loss_val =  5.696665e-06
# epochs =  23 , step =  400 , loss_val =  7.615702e-05
# epochs =  23 , step =  500 , loss_val =  0.01991138
# epochs =  24 , step =  0 , loss_val =  0.004362208
# epochs =  24 , step =  100 , loss_val =  0.0076349746
# epochs =  24 , step =  200 , loss_val =  0.00017731464
# epochs =  24 , step =  300 , loss_val =  0.0007048077
# epochs =  24 , step =  400 , loss_val =  0.006715065
# epochs =  24 , step =  500 , loss_val =  0.0004781793
# epochs =  25 , step =  0 , loss_val =  0.00023208503
# epochs =  25 , step =  100 , loss_val =  0.00588809
# epochs =  25 , step =  200 , loss_val =  0.0004636768
# epochs =  25 , step =  300 , loss_val =  0.00016457727
# epochs =  25 , step =  400 , loss_val =  1.0009856e-05
# epochs =  25 , step =  500 , loss_val =  0.005043816
# epochs =  26 , step =  0 , loss_val =  0.0036021515
# epochs =  26 , step =  100 , loss_val =  0.007444408
# epochs =  26 , step =  200 , loss_val =  0.00015415034
# epochs =  26 , step =  300 , loss_val =  0.0036213181
# epochs =  26 , step =  400 , loss_val =  7.534638e-05
# epochs =  26 , step =  500 , loss_val =  0.00023535028
# epochs =  27 , step =  0 , loss_val =  0.00097347534
# epochs =  27 , step =  100 , loss_val =  0.00026018266
# epochs =  27 , step =  200 , loss_val =  0.00012599892
# epochs =  27 , step =  300 , loss_val =  0.00084265403
# epochs =  27 , step =  400 , loss_val =  0.013938081
# epochs =  27 , step =  500 , loss_val =  0.00011369662
# epochs =  28 , step =  0 , loss_val =  0.00030362437
# epochs =  28 , step =  100 , loss_val =  0.0016602831
# epochs =  28 , step =  200 , loss_val =  0.0894629
# epochs =  28 , step =  300 , loss_val =  0.00016780075
# epochs =  28 , step =  400 , loss_val =  0.00037840754
# epochs =  28 , step =  500 , loss_val =  0.0010237083
# epochs =  29 , step =  0 , loss_val =  6.783427e-05
# epochs =  29 , step =  100 , loss_val =  2.3733817e-05
# epochs =  29 , step =  200 , loss_val =  0.00010139109
# epochs =  29 , step =  300 , loss_val =  0.00012020299
# epochs =  29 , step =  400 , loss_val =  0.0020735168
# epochs =  29 , step =  500 , loss_val =  0.0012243895
#
# elapsed time =  2:21:02.517719
#
# Accuracy =  0.9891
# type(accuracy_val) =  <class 'numpy.float32'> , type(predicted_list_val) =  <class 'numpy.ndarray'> , type(index_label) =  <class 'numpy.ndarray'>
# index_label.shape =  (10000,)
# length of index_label_list =  10000
# false label count =  109
#
# length of index_label_false_list 109
